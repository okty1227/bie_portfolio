# %%
import pandas as pd
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.describe()
# df.columns
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.068733
# std      0.801210   497.183763    0.177034           0.149721   31.869282
# min     -1.000000    -1.000000    0.000000           0.000000   10.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age   python_yn        R_yn  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean   127.183288  100.626011    0.557951   46.591644    0.528302    0.002695
# ...

# %%
df.groupby(['hourly','excel','python_yn', 'R_yn',
       'spark', 'aws'])['avg_salary'].mean()
# Out:
# hourly  excel  python_yn  R_yn  spark  aws
# 0       0      0          0     0      0       94.303279
#                                        1       97.346154
#                                 1      0       56.500000
#                                        1      130.857143
#                1          0     0      0      114.565476
#                                        1      116.233333
#                                 1      0      111.784091
#                                        1      124.363636
#         1      0          0     0      0       84.082759
#                                        1      110.095238
#                                 1      0       95.388889
#                                        1      114.333333
#                1          0     0      0      108.119048
#                                        1      112.293103
#                                 1      0      111.843750
#                                        1      112.045455
# ...

# %% [markdown]
# ## skill matters in regarding to the salary

# %%
df.groupby(['hourly',
       'spark', 'aws'])['avg_salary'].mean()
# Out:
# hourly  spark  aws
# 0       0      0       97.848253
#                1      110.978495
#         1      0      108.244318
#                1      119.031646
# 1       0      0       25.700000
#                1       21.500000
# Name: avg_salary, dtype: float64

# %% [markdown]
# ## the amount of hourly paid data is not balanced with nonhourly paid job -> choose nonhourly job to do comparison

# %%
df.groupby(['hourly']).count().iloc[:,0]
# Out:
# hourly
# 0    718
# 1     24
# Name: Job Title, dtype: int64

# %%
df_nonhour = df[df['hourly']==0]

# %%
df_nonhour.describe()
# Out:
#            Rating      Founded  hourly  employer_provided  min_salary  \
# count  718.000000   718.000000   718.0         718.000000  718.000000
# mean     3.621727  1832.675487     0.0           0.019499   75.871866
# std      0.811907   504.796154     0.0           0.138366   30.795728
# min     -1.000000    -1.000000     0.0           0.000000   15.000000
# 25%      3.300000  1939.000000     0.0           0.000000   54.000000
# 50%      3.700000  1989.000000     0.0           0.000000   71.000000
# 75%      4.000000  2007.000000     0.0           0.000000   92.750000
# max      5.000000  2019.000000     0.0           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age   python_yn        R_yn  \
# count  718.000000  718.000000  718.000000  718.000000  718.000000  718.000000
# mean   130.435933  103.153900    0.564067   46.516713    0.545961    0.002786
# std     44.101293   36.898694    0.496224   54.436165    0.498230    0.052741
# ...

# %%
import matplotlib.pyplot as plt
# df_nonhour[['Rating','min_salary']].plot()
plt.plot(df_nonhour['Rating'], df_nonhour['min_salary'], marker='o', linestyle='-')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\info5100\info5100-hw-assignment\final_project\preprocess.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/info5100/info5100-hw-assignment/final_project/preprocess.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/d%3A/info5100/info5100-hw-assignment/final_project/preprocess.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> # df_nonhour[['Rating','min_salary']].plot()
#       <a href='vscode-notebook-cell:/d%3A/info5100/info5100-hw-assignment/final_project/preprocess.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> plt.plot(df_nonhour['Rating'], df_nonhour['min_salary'], marker='o', linestyle='-')
#
# ModuleNotFoundError: No module named 'matplotlib'
